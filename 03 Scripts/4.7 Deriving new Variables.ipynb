# %% [markdown]
# ## 4.7 Deriving New Variables

# %% [markdown]
# #### The script includes the following points:
#
# ## 1.0 Preparational Steps
# ## 2.0 Practice Steps
# ## 3.0 Task

# %% [markdown]
# ## 1.0 Preparational Steps

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Defining path
path = r'C:\Users\chris\OneDrive\Desktop\Data Analytics CF\202203_Instacart Basket Analysis'

# %%
# Importing ords_prods_merged dataframe
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# Checking imported df 
ords_prods_merged.shape
# Out:
# (32435059, 15)

# %%
# Checking imported df
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
#Checking imported df
ords_prods_merged.tail()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32435054   2977660   206209            13                   1
# 32435055   2977660   206209            13                   1
# 32435056   2977660   206209            13                   1
# 32435057   2977660   206209            13                   1
# 32435058   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 32435054                 12                     7.0        False       14197
# 32435055                 12                     7.0        False       38730
# 32435056                 12                     7.0        False       31477
# 32435057                 12                     7.0        False        6567
# 32435058                 12                     7.0        False       22920
#
#           add_to_cart_order  reordered                           product_name  \
# ...

# %% [markdown]
# Number of columns matches prior data export from 4.6
# No irregularities identified with the head & tail function, except for aisle_id and department_id both having a decimal value although this is not needed.

# %%
# Checking column data types: 
ords_prods_merged.dtypes
# Out:
# order_id                     int64
# user_id                      int64
# order_number                 int64
# orders_day_of_week           int64
# order_hour_of_day            int64
# days_since_prior_order     float64
# first_order                   bool
# product_id                   int64
# add_to_cart_order            int64
# reordered                    int64
# product_name                object
# aisle_id                   float64
# department_id              float64
# prices                     float64
# _merge                    category
# dtype: object

# %%
ords_prods_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only        30200
# right_only           0
# Name: _merge, dtype: int64

# %%
ords_prods_merged['_merge'] == 'both'
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#             ...
# 32435054    True
# 32435055    True
# 32435056    True
# 32435057    True
# 32435058    True
# Name: _merge, Length: 32435059, dtype: bool

# %%
#Test Filter on _merged column to only use columns from the inner join
ords_prods_merged[ords_prods_merged['_merge'] == 'both']
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32435054   2977660   206209            13                   1
# 32435055   2977660   206209            13                   1
# 32435056   2977660   206209            13                   1
# 32435057   2977660   206209            13                   1
# 32435058   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 0                         8                     NaN         True         196
# ...

# %%
# Creating new dataframe to match inner join from exercise 4.6
ords_prods_merged_new = ords_prods_merged[ords_prods_merged['_merge'] == 'both']

# %% [markdown]
# ## 2.0 Practice Steps

# %%
df = ords_prods_merged_new[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %% [markdown]
# ### 2.1 Using a user-defined function

# %%
# Define a function

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Apply price_label function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\chris\AppData\Local\Temp/ipykernel_23816/253661290.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts()
# Out:
# Mid-range product    673183
# Low-range product    314392
# High range            12425
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# ### 2.2 Using loc function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\chris\anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\chris\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
 
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
df['price_range_loc'].value_counts(dropna =  False)
# Out:
# Mid-range product     673183
# Low-range product     314392
# High-range product     12425
# Name: price_range_loc, dtype: int64

# %%
ords_prods_merged_new.loc[ords_prods_merged_new['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\chris\anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\chris\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
ords_prods_merged_new.loc[(ords_prods_merged_new['prices'] <= 15) & (ords_prods_merged_new['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merged_new.loc[ords_prods_merged_new['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merged_new['price_range_loc'].value_counts()
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ### 2.3 Using for loops

# %%
ords_prods_merged_new['orders_day_of_week'].value_counts()
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in ords_prods_merged_new["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merged_new['busiest_day'] = result
# Out:
# C:\Users\chris\AppData\Local\Temp/ipykernel_23816/4010013013.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ords_prods_merged_new['busiest_day'] = result

# %%
ords_prods_merged_new['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %%
ords_prods_merged_new.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %% [markdown]
# ## 3.0 Task

# %% [markdown]
# 1. If you haven’t done so already, complete the instructions in the Exercise for creating the “price_label” and “busiest_day” columns.
#
# --> see 2.2 + 2.3

# %% [markdown]
# 2. Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# Value count for orders_day_of_week
ords_prods_merged_new['orders_day_of_week'].value_counts()
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# The busiest days are 0 and 1, the slowest days are 3 + 4

# %%
# creating variables for the busiest, regular and slowest days

busiest_days = [0, 1]
regular_days = [2, 5, 6]
slowest_days = [3, 4]

# %%
# Using loc and isin functions to create new column 'busiest_days'
ords_prods_merged_new.loc[ords_prods_merged_new['orders_day_of_week'].isin(busiest_days), 'busiest_days'] = 'busiest days'
# Out:
# C:\Users\chris\anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\chris\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
ords_prods_merged_new.loc[ords_prods_merged_new['orders_day_of_week'].isin(regular_days), 'busiest_days'] = 'regular days'

# %%
ords_prods_merged_new.loc[ords_prods_merged_new['orders_day_of_week'].isin(slowest_days), 'busiest_days'] = 'slowest days'

# %% [markdown]
# 3. Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
ords_prods_merged_new.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
ords_prods_merged_new['busiest_days'].value_counts()
# Out:
# regular days    12916111
# busiest days    11864412
# slowest days     7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
# The sums match the sums of the value_counts from the orders_day_of_week column

# %% [markdown]
# 4. When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day."

# %%
ords_prods_merged_new['order_hour_of_day'].value_counts()
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# Defining variables for  most orders, average orders and fewest orders
most_orders = [10, 11, 14, 15, 13, 12, 16, 9]
average_orders = [17, 8, 18, 19, 20, 7, 21, 22]
fewest_orders = [ 23, 6, 0, 1, 5, 2, 4, 3]

# %%
# Creating new column for busiest_period_of_day based on order_hour_of_day
ords_prods_merged_new.loc[ords_prods_merged_new['order_hour_of_day'].isin(most_orders), 'busiest_period_of_day'] = 'Most orders'
# Out:
# C:\Users\chris\anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\chris\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
ords_prods_merged_new.loc[ords_prods_merged_new['order_hour_of_day'].isin(average_orders), 'busiest_period_of_day'] = 'Average orders'

# %%
ords_prods_merged_new.loc[ords_prods_merged_new['order_hour_of_day'].isin(fewest_orders), 'busiest_period_of_day'] = 'Fewest orders'

# %% [markdown]
# 5. Print the frequency for this new column.

# %%
ords_prods_merged_new['busiest_period_of_day'].value_counts()
# Out:
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %%
ords_prods_merged_new['prices'].describe()
# Out:
# count    3.240486e+07
# mean     1.198023e+01
# std      4.956554e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %% [markdown]
# 6. Ensure your notebook is clean and structured and that your code is well commented.
#
# --> Couldn't get rid of the warnings, but otherwise code seems understanable and reasonably commented.

# %% [markdown]
# 7. Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.

# %%
ords_prods_merged_new.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged_new_variables.pkl'))
